# %%
import os
import pandas as pd

# Load the file
operations = pd.read_csv("lista_operacji.csv", skiprows=25, delimiter=';')

operations["#Data operacji"] = pd.to_datetime(operations["#Data operacji"])

# %%
#operations.drop(columns=operations.columns[[2,5,6]], inplace=True)

# %%
operations.dtypes
# Out:
# #Data operacji    datetime64[ns]
# #Opis operacji            object
# #Rachunek                 object
# #Kategoria                object
# #Kwota                    object
# Unnamed: 5               float64
# Unnamed: 6               float64
# dtype: object

# %%
operations.isnull().sum()
# Out:
# #Data operacji      0
# #Opis operacji      0
# #Rachunek           0
# #Kategoria          0
# #Kwota              0
# Unnamed: 5        230
# Unnamed: 6        230
# dtype: int64

# %%
operations
# Out:
#     #Data operacji                                     #Opis operacji  \
# 0       2025-02-24  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 1       2025-02-22  A348 Krakow  ZAKUP PRZY UŻYCIU KARTY W KRAJU  ...
# 2       2025-02-22  Rossmann  ZAKUP PRZY UŻYCIU KARTY W KRAJU     ...
# 3       2025-02-22  ZABKA Z5482 K.2  ZAKUP PRZY UŻYCIU KARTY W KRA...
# 4       2025-02-22  CINEMA CITY KAZIMIERZ  ZAKUP PRZY UŻYCIU KARTY...
# ..             ...                                                ...
# 225     2024-10-04  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 226     2024-10-03  FP ONLINE  ZAKUP PRZY UŻYCIU KARTY - INTERNET ...
# 227     2024-10-02  X-KOM SP. Z O.O.  ZAKUP PRZY UŻYCIU KARTY - IN...
# 228     2024-10-02  KARINKA ., TRANSFER  .                        ...
# 229     2024-10-01  ZABKA Z5083 K.2  ZAKUP PRZY UŻYCIU KARTY W KRA...
#
#                 #Rachunek               #Kategoria         #Kwota  Unnamed: 5  \
# 0    eKonto 2811 ... 1888  Żywność i chemia domowa     -50,50 PLN         NaN
# 1    eKonto 2811 ... 1888            Bez kategorii     -24,95 PLN         NaN
# 2    eKonto 2811 ... 1888  Żywność i chemia domowa     -23,98 PLN         NaN
# 3    eKonto 2811 ... 1888  Żywność i chemia domowa      -2,50 PLN         NaN
# 4    eKonto 2811 ... 1888     Wyjścia i wydarzenia     -35,90 PLN         NaN
# ..                    ...                      ...            ...         ...
# 225  eKonto 2811 ... 1888  Żywność i chemia domowa    -105,94 PLN         NaN
# 226  eKonto 2811 ... 1888           Sport i hobby     -129,00 PLN         NaN
# 227  eKonto 2811 ... 1888              Elektronika  -1 765,00 PLN         NaN
# 228  eKonto 2811 ... 1888            Bez kategorii     -15,00 PLN         NaN
# 229  eKonto 2811 ... 1888  Żywność i chemia domowa      -5,98 PLN         NaN
#
#      Unnamed: 6
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 225         NaN
# 226         NaN
# 227         NaN
# 228         NaN
# 229         NaN
#
# [230 rows x 7 columns]

# %%
operations[['Kwota', 'Waluta']] = operations['#Kwota'].str.extract(r'([-\d,\.]+)\s*(\D+)')

# %%
operations.drop(columns=["#Kwota"], inplace=True)

# %%
operations
# Out:
#     #Data operacji                                     #Opis operacji  \
# 0       2025-02-24  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 1       2025-02-22  A348 Krakow  ZAKUP PRZY UŻYCIU KARTY W KRAJU  ...
# 2       2025-02-22  Rossmann  ZAKUP PRZY UŻYCIU KARTY W KRAJU     ...
# 3       2025-02-22  ZABKA Z5482 K.2  ZAKUP PRZY UŻYCIU KARTY W KRA...
# 4       2025-02-22  CINEMA CITY KAZIMIERZ  ZAKUP PRZY UŻYCIU KARTY...
# ..             ...                                                ...
# 225     2024-10-04  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 226     2024-10-03  FP ONLINE  ZAKUP PRZY UŻYCIU KARTY - INTERNET ...
# 227     2024-10-02  X-KOM SP. Z O.O.  ZAKUP PRZY UŻYCIU KARTY - IN...
# 228     2024-10-02  KARINKA ., TRANSFER  .                        ...
# 229     2024-10-01  ZABKA Z5083 K.2  ZAKUP PRZY UŻYCIU KARTY W KRA...
#
#                 #Rachunek               #Kategoria  Unnamed: 5  Unnamed: 6  \
# 0    eKonto 2811 ... 1888  Żywność i chemia domowa         NaN         NaN
# 1    eKonto 2811 ... 1888            Bez kategorii         NaN         NaN
# 2    eKonto 2811 ... 1888  Żywność i chemia domowa         NaN         NaN
# 3    eKonto 2811 ... 1888  Żywność i chemia domowa         NaN         NaN
# 4    eKonto 2811 ... 1888     Wyjścia i wydarzenia         NaN         NaN
# ..                    ...                      ...         ...         ...
# 225  eKonto 2811 ... 1888  Żywność i chemia domowa         NaN         NaN
# 226  eKonto 2811 ... 1888           Sport i hobby          NaN         NaN
# 227  eKonto 2811 ... 1888              Elektronika         NaN         NaN
# 228  eKonto 2811 ... 1888            Bez kategorii         NaN         NaN
# 229  eKonto 2811 ... 1888  Żywność i chemia domowa         NaN         NaN
#
#        Kwota Waluta
# 0     -50,50    PLN
# 1     -24,95    PLN
# 2     -23,98    PLN
# 3      -2,50    PLN
# 4     -35,90    PLN
# ..       ...    ...
# 225  -105,94    PLN
# 226  -129,00    PLN
# 227       -1
# 228   -15,00    PLN
# 229    -5,98    PLN
#
# [230 rows x 8 columns]

# %%
operations.drop(columns=operations.columns[[2,4,5]], inplace=True)

# %%
operations["#Kategoria"] = operations["#Kategoria"].apply(lambda x: str(x))

# %%
operations

operations.loc[
    operations["#Opis operacji"].str.contains(r'\bBLIK P2P\b', regex=True), "#Kategoria"
] = "BLIK"

operations.loc[
    operations["#Opis operacji"].str.contains(r'\b\bPRZELEW|przelew\b\b', regex=True), "#Kategoria"
] = "PRZELEW"

# %%
operations["#Opis operacji"] = operations["#Opis operacji"].str.strip()

# %%
import re

categories = operations["#Kategoria"].unique().tolist()

operations
# Out:
#     #Data operacji                                     #Opis operacji  \
# 0       2025-02-24  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 1       2025-02-22       A348 Krakow  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 2       2025-02-22          Rossmann  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 3       2025-02-22   ZABKA Z5482 K.2  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 4       2025-02-22  CINEMA CITY KAZIMIERZ  ZAKUP PRZY UŻYCIU KARTY...
# ..             ...                                                ...
# 225     2024-10-04  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 226     2024-10-03      FP ONLINE  ZAKUP PRZY UŻYCIU KARTY - INTERNET
# 227     2024-10-02  X-KOM SP. Z O.O.  ZAKUP PRZY UŻYCIU KARTY - IN...
# 228     2024-10-02  KARINKA ., TRANSFER  .                        ...
# 229     2024-10-01   ZABKA Z5083 K.2  ZAKUP PRZY UŻYCIU KARTY W KRAJU
#
#                   #Kategoria    Kwota Waluta
# 0    Żywność i chemia domowa   -50,50    PLN
# 1              Bez kategorii   -24,95    PLN
# 2    Żywność i chemia domowa   -23,98    PLN
# 3    Żywność i chemia domowa    -2,50    PLN
# 4       Wyjścia i wydarzenia   -35,90    PLN
# ..                       ...      ...    ...
# 225  Żywność i chemia domowa  -105,94    PLN
# 226           Sport i hobby   -129,00    PLN
# 227              Elektronika       -1
# 228                     BLIK   -15,00    PLN
# 229  Żywność i chemia domowa    -5,98    PLN
#
# [230 rows x 5 columns]

# %%
category_missin_operations = operations.loc[operations["#Kategoria"] == "Bez kategorii", ]

# %%
#categories = operations["#Kategoria"].unique()
from tenacity import retry, wait_random_exponential
from openai import OpenAI
import json
from google import genai

OPENAI_API_KEY = "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"
GOOGLE_API_KEY = "AIzaSyBodmtJ0M3FACNavFKov_rfXDDxnNIJWvo"

client = genai.Client(api_key=GOOGLE_API_KEY)
def category_definition_openai():
    
    client = OpenAI(api_key=OPENAI_API_KEY)
    response = client.responses.create(
    model="gpt-3.5-turbo",
    input="Hello."
    )
    
    return response

@retry(wait=wait_random_exponential(multiplier=1, max=60))
def category_definition_gemini(operation):
    
    question = f'''wybież jedna z podanych kategorii, - {categories} - dla podanego zakupu - 
                zakup: "{operation}" - w swojej odpowiedzi podaj tylko i wyłącznie kategorię i nic więcej'''
     
    response = client.models.generate_content(
        model="gemini-2.0-flash-lite",
        contents=[question]
    )
    
    return response.candidates[0].content.parts[0].text.strip()

# %%
for index in operations.index[operations["#Kategoria"] == "Bez kategorii"]:
    response = category_definition_gemini(operations.at[index, "#Opis operacji"])
    operations.at[index, "#Kategoria"] = response
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 2
#       1 for index in operations.index[operations["#Kategoria"] == "Bez kategorii"]:
# ----> 2     response = category_definition_gemini(operations.at[index, "#Opis operacji"])
#       3     operations.at[index, "#Kategoria"] = response
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/tenacity/__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/tenacity/__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     398 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400         self._add_action_func(lambda rs: rs.outcome.result())
#     401         return
#     403     if self.after is not None:
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# Cell In[57], line 27, in category_definition_gemini(operation)
#      21 @retry(wait=wait_random_exponential(multiplier=1, max=60))
#      22 def category_definition_gemini(operation):
#      24     question = f'''wybież jedna z podanych kategorii, - {categories} - dla podanego zakupu -
#      25                 zakup: "{operation}" - w swojej odpowiedzi podaj tylko i wyłącznie kategorię i nic więcej'''
# ---> 27     response = client.models.generate_content(
#      28         model="gemini-2.0-flash-lite",
#      29         contents=[question]
#      30     )
#      32     return response.candidates[0].content.parts[0].text.strip()
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/google/genai/models.py:5630, in Models.generate_content(self, model, contents, config)
#    5628 while remaining_remote_calls_afc > 0:
#    5629   i += 1
# -> 5630   response = self._generate_content(
#    5631       model=model, contents=contents, config=parsed_config
#    5632   )
#    5633   logger.info(f'AFC remote call {i} is done.')
#    5634   remaining_remote_calls_afc -= 1
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/google/genai/models.py:4593, in Models._generate_content(self, model, contents, config)
#    4590 request_dict = _common.convert_to_dict(request_dict)
#    4591 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4593 response_dict = self._api_client.request(
#    4594     'post', path, request_dict, http_options
#    4595 )
#    4597 if self._api_client.vertexai:
#    4598   response_dict = _GenerateContentResponse_from_vertex(
#    4599       self._api_client, response_dict
#    4600   )
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/google/genai/_api_client.py:755, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#     745 def request(
#     746     self,
#     747     http_method: str,
#    (...)    750     http_options: Optional[HttpOptionsOrDict] = None,
#     751 ) -> Union[BaseResponse, Any]:
#     752   http_request = self._build_request(
#     753       http_method, path, request_dict, http_options
#     754   )
# --> 755   response = self._request(http_request, stream=False)
#     756   json_response = response.json
#     757   if not json_response:
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/google/genai/_api_client.py:677, in BaseApiClient._request(self, http_request, stream)
#     673   return HttpResponse(
#     674       response.headers, response if stream else [response.text]
#     675   )
#     676 else:
# --> 677   response = self._httpx_client.request(
#     678       method=http_request.method,
#     679       url=http_request.url,
#     680       headers=http_request.headers,
#     681       content=data,
#     682       timeout=http_request.timeout,
#     683   )
#     684   errors.APIError.raise_for_response(response)
#     685   return HttpResponse(
#     686       response.headers, response if stream else [response.text]
#     687   )
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)    258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)    127     },
#     128 )
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
operations
# Out:
#     #Data operacji                                     #Opis operacji  \
# 0       2025-02-24  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 1       2025-02-22       A348 Krakow  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 2       2025-02-22          Rossmann  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 3       2025-02-22   ZABKA Z5482 K.2  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 4       2025-02-22  CINEMA CITY KAZIMIERZ  ZAKUP PRZY UŻYCIU KARTY...
# ..             ...                                                ...
# 225     2024-10-04  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 226     2024-10-03      FP ONLINE  ZAKUP PRZY UŻYCIU KARTY - INTERNET
# 227     2024-10-02  X-KOM SP. Z O.O.  ZAKUP PRZY UŻYCIU KARTY - IN...
# 228     2024-10-02  KARINKA ., TRANSFER  .                        ...
# 229     2024-10-01   ZABKA Z5083 K.2  ZAKUP PRZY UŻYCIU KARTY W KRAJU
#
#                   #Kategoria    Kwota Waluta
# 0    Żywność i chemia domowa   -50,50    PLN
# 1              Bez kategorii   -24,95    PLN
# 2    Żywność i chemia domowa   -23,98    PLN
# 3    Żywność i chemia domowa    -2,50    PLN
# 4       Wyjścia i wydarzenia   -35,90    PLN
# ..                       ...      ...    ...
# 225  Żywność i chemia domowa  -105,94    PLN
# 226           Sport i hobby   -129,00    PLN
# 227              Elektronika       -1
# 228                     BLIK   -15,00    PLN
# 229  Żywność i chemia domowa    -5,98    PLN
#
# [230 rows x 5 columns]

# %%
operations["Kwota"] = operations["Kwota"].str.replace(',','.')

# %%
operations["Kwota"] = operations["Kwota"].astype('float')

# %%
operations
# Out:
#     #Data operacji                                     #Opis operacji  \
# 0       2025-02-24  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 1       2025-02-22       A348 Krakow  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 2       2025-02-22          Rossmann  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 3       2025-02-22   ZABKA Z5482 K.2  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 4       2025-02-22  CINEMA CITY KAZIMIERZ  ZAKUP PRZY UŻYCIU KARTY...
# ..             ...                                                ...
# 225     2024-10-04  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 226     2024-10-03      FP ONLINE  ZAKUP PRZY UŻYCIU KARTY - INTERNET
# 227     2024-10-02  X-KOM SP. Z O.O.  ZAKUP PRZY UŻYCIU KARTY - IN...
# 228     2024-10-02  KARINKA ., TRANSFER  .                        ...
# 229     2024-10-01   ZABKA Z5083 K.2  ZAKUP PRZY UŻYCIU KARTY W KRAJU
#
#                   #Kategoria   Kwota Waluta
# 0    Żywność i chemia domowa  -50.50    PLN
# 1        Jedzenie poza domem  -24.95    PLN
# 2    Żywność i chemia domowa  -23.98    PLN
# 3    Żywność i chemia domowa   -2.50    PLN
# 4       Wyjścia i wydarzenia  -35.90    PLN
# ..                       ...     ...    ...
# 225  Żywność i chemia domowa -105.94    PLN
# 226           Sport i hobby  -129.00    PLN
# 227              Elektronika   -1.00
# 228                     BLIK  -15.00    PLN
# 229  Żywność i chemia domowa   -5.98    PLN
#
# [230 rows x 5 columns]

# %%
operations.sort_values("#Data operacji", ascending=False)
# Out:
#     #Data operacji                                     #Opis operacji  \
# 0       2025-02-24  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 4       2025-02-22  CINEMA CITY KAZIMIERZ  ZAKUP PRZY UŻYCIU KARTY...
# 5       2025-02-22  WWW.CINEMA-CITY.PL                            ...
# 1       2025-02-22       A348 Krakow  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 3       2025-02-22   ZABKA Z5482 K.2  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# ..             ...                                                ...
# 225     2024-10-04  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 226     2024-10-03      FP ONLINE  ZAKUP PRZY UŻYCIU KARTY - INTERNET
# 227     2024-10-02  X-KOM SP. Z O.O.  ZAKUP PRZY UŻYCIU KARTY - IN...
# 228     2024-10-02  KARINKA ., TRANSFER  .                        ...
# 229     2024-10-01   ZABKA Z5083 K.2  ZAKUP PRZY UŻYCIU KARTY W KRAJU
#
#                   #Kategoria    Kwota Waluta
# 0    Żywność i chemia domowa   -50,50    PLN
# 4       Wyjścia i wydarzenia   -35,90    PLN
# 5       Wyjścia i wydarzenia   -67,80    PLN
# 1              Bez kategorii   -24,95    PLN
# 3    Żywność i chemia domowa    -2,50    PLN
# ..                       ...      ...    ...
# 225  Żywność i chemia domowa  -105,94    PLN
# 226           Sport i hobby   -129,00    PLN
# 227              Elektronika       -1
# 228                     BLIK   -15,00    PLN
# 229  Żywność i chemia domowa    -5,98    PLN
#
# [230 rows x 5 columns]

# %%
date_from = operations["#Data operacji"].iloc[-1]
date_to = operations["#Data operacji"].iloc[0]

# %%
date_to
# Out:
# Timestamp('2025-02-24 00:00:00')

# %%
date_from
# Out:
# Timestamp('2024-10-01 00:00:00')

# %%
from datetime import date
operation_date= date(2024, 5, 1)
operation_date
# Out:
# datetime.date(2024, 5, 1)

# %%
date_from.date()
# Out:
# datetime.date(2024, 10, 1)

# %%
operation_date >= date_from.date()
# Out:
# False

# %%
operation_date <= date_to

# %%
data_file = operations
data_file
# Out:
#     #Data operacji                                     #Opis operacji  \
# 0       2025-02-24  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 1       2025-02-22       A348 Krakow  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 2       2025-02-22          Rossmann  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 3       2025-02-22   ZABKA Z5482 K.2  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 4       2025-02-22  CINEMA CITY KAZIMIERZ  ZAKUP PRZY UŻYCIU KARTY...
# ..             ...                                                ...
# 225     2024-10-04  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 226     2024-10-03      FP ONLINE  ZAKUP PRZY UŻYCIU KARTY - INTERNET
# 227     2024-10-02  X-KOM SP. Z O.O.  ZAKUP PRZY UŻYCIU KARTY - IN...
# 228     2024-10-02  KARINKA ., TRANSFER  .                        ...
# 229     2024-10-01   ZABKA Z5083 K.2  ZAKUP PRZY UŻYCIU KARTY W KRAJU
#
#                   #Kategoria    Kwota Waluta
# 0    Żywność i chemia domowa   -50,50    PLN
# 1              Bez kategorii   -24,95    PLN
# 2    Żywność i chemia domowa   -23,98    PLN
# 3    Żywność i chemia domowa    -2,50    PLN
# 4       Wyjścia i wydarzenia   -35,90    PLN
# ..                       ...      ...    ...
# 225  Żywność i chemia domowa  -105,94    PLN
# 226           Sport i hobby   -129,00    PLN
# 227              Elektronika       -1
# 228                     BLIK   -15,00    PLN
# 229  Żywność i chemia domowa    -5,98    PLN
#
# [230 rows x 5 columns]

# %%
import sys
import os

sys.path.append(os.path.abspath("../backend"))  # <-- kluczowa zmiana

from app.database.models import Operation

user_id = 2

operation = [Operation(
                user_id=user_id,
                operation_date=row["#Data operacji"],
                category=row["#Kategoria"],
                description=row["#Opis operacji"],
                value=row["Kwota"],
                currency=row["Waluta"]) 
                for _, row in data_file.iterrows()]

# %%
from typing import List

list_operation : List[Operation] = [[o.operation_id, o.user_id, o.operation_date, o.category, o.description, o.value, o.currency]  for o in operation]
pd.DataFrame(list_operation)
# Out:
#         0  1          2                        3  \
# 0    None  2 2025-02-24  Żywność i chemia domowa
# 1    None  2 2025-02-22            Bez kategorii
# 2    None  2 2025-02-22  Żywność i chemia domowa
# 3    None  2 2025-02-22  Żywność i chemia domowa
# 4    None  2 2025-02-22     Wyjścia i wydarzenia
# ..    ... ..        ...                      ...
# 225  None  2 2024-10-04  Żywność i chemia domowa
# 226  None  2 2024-10-03           Sport i hobby
# 227  None  2 2024-10-02              Elektronika
# 228  None  2 2024-10-02                     BLIK
# 229  None  2 2024-10-01  Żywność i chemia domowa
#
#                                                      4        5    6
# 0    JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...   -50,50  PLN
# 1         A348 Krakow  ZAKUP PRZY UŻYCIU KARTY W KRAJU   -24,95  PLN
# 2            Rossmann  ZAKUP PRZY UŻYCIU KARTY W KRAJU   -23,98  PLN
# 3     ZABKA Z5482 K.2  ZAKUP PRZY UŻYCIU KARTY W KRAJU    -2,50  PLN
# 4    CINEMA CITY KAZIMIERZ  ZAKUP PRZY UŻYCIU KARTY...   -35,90  PLN
# ..                                                 ...      ...  ...
# 225  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...  -105,94  PLN
# 226      FP ONLINE  ZAKUP PRZY UŻYCIU KARTY - INTERNET  -129,00  PLN
# 227  X-KOM SP. Z O.O.  ZAKUP PRZY UŻYCIU KARTY - IN...       -1
# 228  KARINKA ., TRANSFER  .                        ...   -15,00  PLN
# 229   ZABKA Z5083 K.2  ZAKUP PRZY UŻYCIU KARTY W KRAJU    -5,98  PLN
#
# [230 rows x 7 columns]

# %%
saved_operations = operations.iloc[0:2, :].sort_values(by="Kwota", ascending=True)

new_operations = operations.iloc[0:3, :]

# %%
saved_operations
# Out:
#   #Data operacji                                     #Opis operacji  \
# 1     2025-02-22       A348 Krakow  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 0     2025-02-24  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
#
#                 #Kategoria   Kwota Waluta
# 1            Bez kategorii  -24,95    PLN
# 0  Żywność i chemia domowa  -50,50    PLN

# %%
new_operations
# Out:
#   #Data operacji                                     #Opis operacji  \
# 0     2025-02-24  JMP S.A. BIEDRONKA 5987  ZAKUP PRZY UŻYCIU KAR...
# 1     2025-02-22       A348 Krakow  ZAKUP PRZY UŻYCIU KARTY W KRAJU
# 2     2025-02-22          Rossmann  ZAKUP PRZY UŻYCIU KARTY W KRAJU
#
#                 #Kategoria   Kwota Waluta
# 0  Żywność i chemia domowa  -50,50    PLN
# 1            Bez kategorii  -24,95    PLN
# 2  Żywność i chemia domowa  -23,98    PLN

# %%
merged_df = new_operations.merge(saved_operations, how='left', indicator=True)

operations_to_add = merged_df[merged_df['_merge'] == 'left_only'].drop(columns=['_merge'])

# %%
operations_to_add
# Out:
#   #Data operacji                             #Opis operacji  \
# 2     2025-02-22  Rossmann  ZAKUP PRZY UŻYCIU KARTY W KRAJU
#
#                 #Kategoria   Kwota Waluta
# 2  Żywność i chemia domowa  -23,98    PLN

# %%
 # zakładam, że operations to DataFrame wcześniej załadowany

import sys
import os

sys.path.append(os.path.abspath("../backend"))  # <-- kluczowa zmiana

from backend.app.database.models import Operation

operations = [
    Operation(**row.to_dict()) for _, row in data_file.iterrows()
]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 11
#       6 sys.path.append(os.path.abspath("../backend"))  # <-- kluczowa zmiana
#       8 from backend.app.database.models.models import Operation
#      10 operations = [
# ---> 11     Operation(**row.to_dict()) for _, row in data_file.iterrows()
#      12 ]
#
# File <string>:4, in __init__(self, **kwargs)
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/sqlalchemy/orm/state.py:571, in InstanceState._initialize_instance(*mixed, **kwargs)
#     569     manager.original_init(*mixed[1:], **kwargs)
#     570 except:
# --> 571     with util.safe_reraise():
#     572         manager.dispatch.init_failure(self, args, kwargs)
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/sqlalchemy/orm/state.py:569, in InstanceState._initialize_instance(*mixed, **kwargs)
#     566 manager.dispatch.init(self, args, kwargs)
#     568 try:
# --> 569     manager.original_init(*mixed[1:], **kwargs)
#     570 except:
#     571     with util.safe_reraise():
#
# File ~/miniconda3/envs/finance_app/lib/python3.13/site-packages/sqlalchemy/orm/decl_base.py:2175, in _declarative_constructor(self, **kwargs)
#    2173 for k in kwargs:
#    2174     if not hasattr(cls_, k):
# -> 2175         raise TypeError(
#    2176             "%r is an invalid keyword argument for %s" % (k, cls_.__name__)
#    2177         )
#    2178     setattr(self, k, kwargs[k])
#
# TypeError: '#Data operacji' is an invalid keyword argument for Operation

# %%
data_file = operations  # zakładam, że operations to DataFrame wcześniej załadowany

import sys
import os

sys.path.append(os.path.abspath(".."))  # <-- kluczowa zmiana

from backend.app.database.models import Operation

operations = [
    Operation(**row.to_dict()) for _, row in data_file.iterrows()
]
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[33], line 8
#
#       4 import os
#
#       6 sys.path.append(os.path.abspath(".."))  # <-- kluczowa zmiana
#
# ----> 8 from app.database.models.models import Operation
#
#      10 operations = [
#
#      11     Operation(**row.to_dict()) for _, row in data_file.iterrows()
#
#      12 ]
#
#
#
# ModuleNotFoundError: No module named 'app'

# %%
df1=pd.DataFrame({'A':[1,2],'B':[2,2]})
df2=pd.DataFrame({'A':[1],'B':[2]})

# %%
df1
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4
# 3  3  4

# %%
df2
# Out:
#    A  B
# 0  1  2

# %%
pd.concat([df1, df2]).drop_duplicates(keep=False)
# Out:
#    A  B
# 1  2  3

# %%
df1[~df1.apply(tuple,1).isin(df2.apply(tuple,1))].shape[0]
# Out:
# 1
